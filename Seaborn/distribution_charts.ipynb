# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips') #Cargar el dataset por defecto "tips" para hacer pruebas

# %%
tips.head(10) #head se le pasa el número de registros mostrar
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.distplot(tips['total_bill']) #Crear un gráfico de tipo histograma de la columna total_bill
# Out:
# C:\Users\erick\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'], bins = 20) #bins es el número de barra del histograma
# Out:
# C:\Users\erick\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['tip'], bins = 20)
# Out:
# C:\Users\erick\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.jointplot(x='total_bill', y='tip', data=tips) #Comparar variables por medio de gráfico histogramas

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex') #Comparar variables por medio de gráfico hexadecimal (kind=hex)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg') #Comparar variables por medio de gráfico regresión lineal (kind=reg)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde') #Comparar variables por medio de gráfico de densidad (kind=kde)

# %%
sns.pairplot(tips) #Comparar todas las columnas

# %%
sns.pairplot(tips, hue='sex') #Comparar con las columnas, hue se le pasa la columna con texto a comparar

# %%
sns.pairplot(tips, hue='size')

# %%
sns.rugplot(tips['total_bill']) #Mostrar por medio de un gráfico, medinate una raya cada uno de los datos que hay en el dataset
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.rugplot(tips['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>
