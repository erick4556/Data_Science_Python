# %%
#Ficheros html
import pandas as pd

# %%
web_page = "https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n"

# %%
data = pd.read_html(web_page) #Leer la webd

# %%
type(data) #Saber el tipo de datos
# Out:
# list

# %%
dataframe = data[0]
dataframe.head(10) #Ver las primeras 10 posiciones
# Out:
#   N.º País (o territorio dependiente)  \
# 0   1                      China[13]​
# 1   2                           India
# 2   3                  Estados Unidos
# 3   4                       Indonesia
# 4   5                        Pakistán
# 5   6                         Nigeria
# 6   7                          Brasil
# 7   8                       Bangladés
# 8   9                      Rusia[14]​
# 9  10                          México
#
#   Proyecciónexponencialde lapoblaciónal1/7/2022[8]​ % deltotalmun-dial  \
# 0                                     1 415 943 000               1792
# 1                                     1 408 395 000               1782
# 2                                       332 250 000                420
# 3                                       276 104 000                349
# 4                                       235 409 000                298
# 5                                       218 432 000                276
# ...
